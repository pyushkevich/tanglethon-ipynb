# %% [markdown]
# Experiment with DeepCluster
# =====

# %%
# Set up
import os
import sys
sys.path.insert(0, os.path.abspath('./deepcluster'))

# %%
# Load deepcluster utilities
from deepcluster.util import load_model
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.utils
import torch.utils.data
import matplotlib.pyplot as plt
import numpy as np
import openslide
import math

# %%
# Read the trained model
model_file=os.path.abspath('./exp01/checkpoint.200th.tar')
model = load_model(model_file)
model.cuda()
# Out:
# => loading checkpoint '/home/pyushkevich/resnet/nissl_cluster/exp01/checkpoint.200th.tar'
# Loaded
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(2, 96, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace)
#     (7): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace)
#     (11): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU(inplace)
#     (14): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace)
#     (17): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#   )
#   (top_layer): Linear(in_features=4096, out_features=20, bias=True)
#   (sobel): Sequential(
#     (0): Conv2d(3, 1, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(1, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %% [markdown]
# Evaluate model on validation subset
# -----

# %%
# Load validation dataset
eval_path='/home/pyushkevich/data/nissl/patches/val'
tra = [transforms.Resize(256),
       transforms.CenterCrop(224),
       transforms.ToTensor(),
       transforms.Normalize(mean=[0.485, 0.456, 0.406],
                            std=[0.229, 0.224, 0.225])]
dataset = datasets.ImageFolder(eval_path, transform=transforms.Compose(tra))

# %%
dataloader = torch.utils.data.DataLoader(dataset,
                                         batch_size=64,
                                         num_workers=4,
                                         pin_memory=True, shuffle=True)

# %%
# %matplotlib inline
def show_torch(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='bilinear')
    
# Display individual clusters
def show_cluster(C, k, p=16):
    n = len(C[k])
    idx = np.random.choice(n,min(n,p),replace=False)
    T = torch.tensor(C[k][idx,:,:,:])
    show_torch(torchvision.utils.make_grid(T,normalize=True,padding=10).cpu())

# %%
# Load some example patches
plt.figure(figsize=(16,8))
_, (test_tensor, _) = next(enumerate(dataloader))
show_torch(torchvision.utils.make_grid(test_tensor, normalize=True,padding=10).cpu())

# %%
# Do the evaluation on a mini-batch
model.eval()
cluster=[]
img_cluster=[np.empty((0,3,224,224))]*20
for i, (input_tensor, _) in enumerate(dataloader):
    input_tensor = input_tensor.cuda(non_blocking=True)
    with torch.no_grad():
        output = model(input_tensor)
        batch_cluster = output.cpu().max(1)[1].tolist()
        cluster = cluster + batch_cluster
        for j,j_cluster in enumerate(batch_cluster):
            img_cluster[j_cluster] = np.append(img_cluster[j_cluster],
                                               np.expand_dims(input_tensor[j].cpu().numpy(),0),
                                               axis=0)

# %%
# Display class frequencies
plt.bar(x=range(20),height=list(map(len,img_cluster)));

# %%
plt.figure(figsize=(8,8))
show_cluster(img_cluster,9,32)

# %%
plt.figure(figsize=(8,8))
show_cluster(img_cluster,14,32)

# %%
plt.figure(figsize=(8,8))
show_cluster(img_cluster,19,32)

# %%
plt.figure(figsize=(8,8))
show_cluster(img_cluster,3,32)

# %% [markdown]
# Parse a whole NISSL slide
# -----

# %%
osl=openslide.OpenSlide('/home/pyushkevich/data/raw/HNL-34-18_HR3a_NISSL_24.tif')

# %%
plt.figure(figsize=(16,8))
plt.imshow(osl.get_thumbnail((512,512)), extent=(0,osl.level_dimensions[0][0]/224,osl.level_dimensions[0][1]/224,0))
ax = plt.gca()
plt.xticks(np.arange(0,osl.level_dimensions[0][0]/224,100));
plt.yticks(np.arange(0,osl.level_dimensions[0][1]/224,100));

# %%
# Function to perform clustering on a window
window = osl.read_region((56000,44800),0,(4096,4096)).convert("RGB")
plt.imshow(window)

# %%
# Transforms for this
tran_norm = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
def run_model_on_window(model, window):
    W_patch = W.unfold(1,256,256).unfold(2,256,256).permute(1,2,0,3,4).reshape(-1,3,256,256)
    k = int(math.sqrt(W_patch.shape[0]))
    W_patch_crop = W_patch[:,:,16:240,16:240]
    with torch.no_grad():
        W_result = model(W_patch_crop)
    return W_result.reshape(k,k,W_result.shape[1])

# %%
import torch.nn
W=tran_norm(window).cuda()
R=run_model_on_window(model, W)
R.shape
# Out:
# torch.Size([16, 16, 20])

# %%
# Break the image into patches, for each patch, run the model on it
(w,h) = osl.level_dimensions[0]

# Size of the input window and number of windows
window_size=7168
nw_x,nw_y = math.ceil(w/window_size),math.ceil(h/window_size)

# Output window size and output dimensions
output_window_size = int(window_size / 256)
(ow,oh) = nw_x * output_window_size, nw_y * output_window_size
output = np.zeros((ow,oh,20))

for i_x in range(nw_x):
    for i_y in range(nw_y):
        
        # The corner of the region
        c_x,c_y = window_size * i_x, window_size * i_y
        window = osl.read_region((c_x,c_y), 0, (window_size,window_size)).convert("RGB")
        W=tran_norm(window).cuda()
        R=run_model_on_window(model, W).cpu().numpy().transpose((1,0,2))
        
        co_x,co_y = output_window_size * i_x, output_window_size * i_y
        output[co_x:co_x+output_window_size,co_y:co_y+output_window_size,:] = R
        
        print('Finished (%d,%d) of (%d,%d)' % (i_x,i_y,nw_x,nw_y))
# Out:
# Finished (0,0) of (15,20)
# Finished (0,1) of (15,20)
# Finished (0,2) of (15,20)
# Finished (0,3) of (15,20)
# Finished (0,4) of (15,20)
# Finished (0,5) of (15,20)
# Finished (0,6) of (15,20)
# Finished (0,7) of (15,20)
# Finished (0,8) of (15,20)
# Finished (0,9) of (15,20)
# Finished (0,10) of (15,20)
# Finished (0,11) of (15,20)
# Finished (0,12) of (15,20)
# Finished (0,13) of (15,20)
# Finished (0,14) of (15,20)
# Finished (0,15) of (15,20)
# Finished (0,16) of (15,20)
# Finished (0,17) of (15,20)
# Finished (0,18) of (15,20)
# Finished (0,19) of (15,20)
# Finished (1,0) of (15,20)
# Finished (1,1) of (15,20)
# Finished (1,2) of (15,20)
# Finished (1,3) of (15,20)
# Finished (1,4) of (15,20)
# Finished (1,5) of (15,20)
# Finished (1,6) of (15,20)
# Finished (1,7) of (15,20)
# Finished (1,8) of (15,20)
# Finished (1,9) of (15,20)
# Finished (1,10) of (15,20)
# Finished (1,11) of (15,20)
# Finished (1,12) of (15,20)
# Finished (1,13) of (15,20)
# Finished (1,14) of (15,20)
# Finished (1,15) of (15,20)
# Finished (1,16) of (15,20)
# Finished (1,17) of (15,20)
# Finished (1,18) of (15,20)
# Finished (1,19) of (15,20)
# Finished (2,0) of (15,20)
# Finished (2,1) of (15,20)
# Finished (2,2) of (15,20)
# Finished (2,3) of (15,20)
# Finished (2,4) of (15,20)
# Finished (2,5) of (15,20)
# Finished (2,6) of (15,20)
# Finished (2,7) of (15,20)
# Finished (2,8) of (15,20)
# Finished (2,9) of (15,20)
# Finished (2,10) of (15,20)
# Finished (2,11) of (15,20)
# Finished (2,12) of (15,20)
# Finished (2,13) of (15,20)
# Finished (2,14) of (15,20)
# Finished (2,15) of (15,20)
# Finished (2,16) of (15,20)
# Finished (2,17) of (15,20)
# Finished (2,18) of (15,20)
# Finished (2,19) of (15,20)
# Finished (3,0) of (15,20)
# Finished (3,1) of (15,20)
# Finished (3,2) of (15,20)
# Finished (3,3) of (15,20)
# Finished (3,4) of (15,20)
# Finished (3,5) of (15,20)
# Finished (3,6) of (15,20)
# Finished (3,7) of (15,20)
# Finished (3,8) of (15,20)
# Finished (3,9) of (15,20)
# Finished (3,10) of (15,20)
# Finished (3,11) of (15,20)
# Finished (3,12) of (15,20)
# Finished (3,13) of (15,20)
# Finished (3,14) of (15,20)
# Finished (3,15) of (15,20)
# Finished (3,16) of (15,20)
# Finished (3,17) of (15,20)
# Finished (3,18) of (15,20)
# Finished (3,19) of (15,20)
# Finished (4,0) of (15,20)
# Finished (4,1) of (15,20)
# Finished (4,2) of (15,20)
# Finished (4,3) of (15,20)
# Finished (4,4) of (15,20)
# Finished (4,5) of (15,20)
# Finished (4,6) of (15,20)
# Finished (4,7) of (15,20)
# Finished (4,8) of (15,20)
# Finished (4,9) of (15,20)
# Finished (4,10) of (15,20)
# Finished (4,11) of (15,20)
# Finished (4,12) of (15,20)
# Finished (4,13) of (15,20)
# Finished (4,14) of (15,20)
# Finished (4,15) of (15,20)
# Finished (4,16) of (15,20)
# Finished (4,17) of (15,20)
# Finished (4,18) of (15,20)
# Finished (4,19) of (15,20)
# Finished (5,0) of (15,20)
# Finished (5,1) of (15,20)
# Finished (5,2) of (15,20)
# Finished (5,3) of (15,20)
# Finished (5,4) of (15,20)
# Finished (5,5) of (15,20)
# Finished (5,6) of (15,20)
# Finished (5,7) of (15,20)
# Finished (5,8) of (15,20)
# Finished (5,9) of (15,20)
# Finished (5,10) of (15,20)
# Finished (5,11) of (15,20)
# Finished (5,12) of (15,20)
# Finished (5,13) of (15,20)
# Finished (5,14) of (15,20)
# Finished (5,15) of (15,20)
# Finished (5,16) of (15,20)
# Finished (5,17) of (15,20)
# Finished (5,18) of (15,20)
# Finished (5,19) of (15,20)
# Finished (6,0) of (15,20)
# Finished (6,1) of (15,20)
# Finished (6,2) of (15,20)
# Finished (6,3) of (15,20)
# Finished (6,4) of (15,20)
# Finished (6,5) of (15,20)
# Finished (6,6) of (15,20)
# Finished (6,7) of (15,20)
# Finished (6,8) of (15,20)
# Finished (6,9) of (15,20)
# Finished (6,10) of (15,20)
# Finished (6,11) of (15,20)
# Finished (6,12) of (15,20)
# Finished (6,13) of (15,20)
# Finished (6,14) of (15,20)
# Finished (6,15) of (15,20)
# Finished (6,16) of (15,20)
# Finished (6,17) of (15,20)
# Finished (6,18) of (15,20)
# Finished (6,19) of (15,20)
# Finished (7,0) of (15,20)
# Finished (7,1) of (15,20)
# Finished (7,2) of (15,20)
# Finished (7,3) of (15,20)
# Finished (7,4) of (15,20)
# Finished (7,5) of (15,20)
# Finished (7,6) of (15,20)
# Finished (7,7) of (15,20)
# Finished (7,8) of (15,20)
# Finished (7,9) of (15,20)
# Finished (7,10) of (15,20)
# Finished (7,11) of (15,20)
# Finished (7,12) of (15,20)
# Finished (7,13) of (15,20)
# Finished (7,14) of (15,20)
# Finished (7,15) of (15,20)
# Finished (7,16) of (15,20)
# Finished (7,17) of (15,20)
# Finished (7,18) of (15,20)
# Finished (7,19) of (15,20)
# Finished (8,0) of (15,20)
# Finished (8,1) of (15,20)
# Finished (8,2) of (15,20)
# Finished (8,3) of (15,20)
# Finished (8,4) of (15,20)
# Finished (8,5) of (15,20)
# Finished (8,6) of (15,20)
# Finished (8,7) of (15,20)
# Finished (8,8) of (15,20)
# Finished (8,9) of (15,20)
# Finished (8,10) of (15,20)
# Finished (8,11) of (15,20)
# Finished (8,12) of (15,20)
# Finished (8,13) of (15,20)
# Finished (8,14) of (15,20)
# Finished (8,15) of (15,20)
# Finished (8,16) of (15,20)
# Finished (8,17) of (15,20)
# Finished (8,18) of (15,20)
# Finished (8,19) of (15,20)
# Finished (9,0) of (15,20)
# Finished (9,1) of (15,20)
# Finished (9,2) of (15,20)
# Finished (9,3) of (15,20)
# Finished (9,4) of (15,20)
# Finished (9,5) of (15,20)
# Finished (9,6) of (15,20)
# Finished (9,7) of (15,20)
# Finished (9,8) of (15,20)
# Finished (9,9) of (15,20)
# Finished (9,10) of (15,20)
# Finished (9,11) of (15,20)
# Finished (9,12) of (15,20)
# Finished (9,13) of (15,20)
# Finished (9,14) of (15,20)
# Finished (9,15) of (15,20)
# Finished (9,16) of (15,20)
# Finished (9,17) of (15,20)
# Finished (9,18) of (15,20)
# Finished (9,19) of (15,20)
# Finished (10,0) of (15,20)
# Finished (10,1) of (15,20)
# Finished (10,2) of (15,20)
# Finished (10,3) of (15,20)
# Finished (10,4) of (15,20)
# Finished (10,5) of (15,20)
# Finished (10,6) of (15,20)
# Finished (10,7) of (15,20)
# Finished (10,8) of (15,20)
# Finished (10,9) of (15,20)
# Finished (10,10) of (15,20)
# Finished (10,11) of (15,20)
# Finished (10,12) of (15,20)
# Finished (10,13) of (15,20)
# Finished (10,14) of (15,20)
# Finished (10,15) of (15,20)
# Finished (10,16) of (15,20)
# Finished (10,17) of (15,20)
# Finished (10,18) of (15,20)
# Finished (10,19) of (15,20)
# Finished (11,0) of (15,20)
# Finished (11,1) of (15,20)
# Finished (11,2) of (15,20)
# Finished (11,3) of (15,20)
# Finished (11,4) of (15,20)
# Finished (11,5) of (15,20)
# Finished (11,6) of (15,20)
# Finished (11,7) of (15,20)
# Finished (11,8) of (15,20)
# Finished (11,9) of (15,20)
# Finished (11,10) of (15,20)
# Finished (11,11) of (15,20)
# Finished (11,12) of (15,20)
# Finished (11,13) of (15,20)
# Finished (11,14) of (15,20)
# Finished (11,15) of (15,20)
# Finished (11,16) of (15,20)
# Finished (11,17) of (15,20)
# Finished (11,18) of (15,20)
# Finished (11,19) of (15,20)
# Finished (12,0) of (15,20)
# Finished (12,1) of (15,20)
# Finished (12,2) of (15,20)
# Finished (12,3) of (15,20)
# Finished (12,4) of (15,20)
# Finished (12,5) of (15,20)
# Finished (12,6) of (15,20)
# Finished (12,7) of (15,20)
# Finished (12,8) of (15,20)
# Finished (12,9) of (15,20)
# Finished (12,10) of (15,20)
# Finished (12,11) of (15,20)
# Finished (12,12) of (15,20)
# Finished (12,13) of (15,20)
# Finished (12,14) of (15,20)
# Finished (12,15) of (15,20)
# Finished (12,16) of (15,20)
# Finished (12,17) of (15,20)
# Finished (12,18) of (15,20)
# Finished (12,19) of (15,20)
# Finished (13,0) of (15,20)
# Finished (13,1) of (15,20)
# Finished (13,2) of (15,20)
# Finished (13,3) of (15,20)
# Finished (13,4) of (15,20)
# Finished (13,5) of (15,20)
# Finished (13,6) of (15,20)
# Finished (13,7) of (15,20)
# Finished (13,8) of (15,20)
# Finished (13,9) of (15,20)
# Finished (13,10) of (15,20)
# Finished (13,11) of (15,20)
# Finished (13,12) of (15,20)
# Finished (13,13) of (15,20)
# Finished (13,14) of (15,20)
# Finished (13,15) of (15,20)
# Finished (13,16) of (15,20)
# Finished (13,17) of (15,20)
# Finished (13,18) of (15,20)
# Finished (13,19) of (15,20)
# Finished (14,0) of (15,20)
# Finished (14,1) of (15,20)
# Finished (14,2) of (15,20)
# Finished (14,3) of (15,20)
# Finished (14,4) of (15,20)
# Finished (14,5) of (15,20)
# Finished (14,6) of (15,20)
# Finished (14,7) of (15,20)
# Finished (14,8) of (15,20)
# Finished (14,9) of (15,20)
# Finished (14,10) of (15,20)
# Finished (14,11) of (15,20)
# Finished (14,12) of (15,20)
# Finished (14,13) of (15,20)
# Finished (14,14) of (15,20)
# Finished (14,15) of (15,20)
# Finished (14,16) of (15,20)
# Finished (14,17) of (15,20)
# Finished (14,18) of (15,20)
# Finished (14,19) of (15,20)

# %%
# The output comes out padded and transposed. Fix that
Z = output[0:math.ceil(w/256),0:math.ceil(h/256),:].transpose(1,0,2)

# %%
plt.imshow(Z[:,:,14])

# %%
Z.shape
# Out:
# (534, 395, 20)

# %%
plt.figure(figsize=(18,12))
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(Z[:,:,i].transpose())

# %%
import scipy.cluster.vq
from sklearn import mixture

# %%
Z.reshape(-1,20).shape
# Out:
# (210930, 20)

# %%
g = mixture.GaussianMixture(n_components=3)
g.fit(Z.reshape(-1,20))
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=3, n_init=1, precisions_init=None,
#                 random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#                 verbose_interval=10, warm_start=False, weights_init=None)

# %%
prob = g.predict_proba(Z.reshape(-1,20)).reshape(Z.shape[0], Z.shape[1], 3)

# %%
plt.imshow(prob[:,:,0] * 100 + prob[:,:,2] * 200, cmap='gray')
